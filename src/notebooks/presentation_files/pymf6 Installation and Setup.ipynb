# %% [markdown]
# # MODFLOW 6 Lab: Customizing for Flow, Transport and Geothermal Modeling

# %% [markdown]
# ## Installation & Setup of pymf6

# %% [markdown]
# pymf6 is a Python package. There are two ways to install pymf6:
#
# 1. As a conda package from the hydrocmputing channel
#
# 2. As a standard Python package from PyPi

# %% [markdown]
# ## Installing pymf6 with Pixi

# %% [markdown]
# Install it on the Pixi workspace created before:

# %% [raw]
# pixi add pymf6

# %% [markdown]
# ## Installing using Conda with Miniforge, Miniconda or Anaconda

# %% [markdown]
# Alternatives to using Pixi are Miniforge, Miniconda, or Anaconda. Miniforge is a minimal conda installer with the conda-forge channel as the default channel.
#
# Anaconda is a Python distribution with many Python packages. Miniconda is a much smaller version of the Anaconda Distribution with a few packages. Make sure the Anaconda license works for you before using this option. Otherwise, use Miniforge, or our recommendation Pixi.
#
# After installing Miniconda or Anaconda, the command conda should be available in a terminal window:

# %% [raw]
# conda
# usage: conda [-h] [-v] [--no-plugins] [-V] COMMAND ...
#
# conda is a tool for managing and deploying applications, environments and packages.

# %% [markdown]
# ### Installing pymf6
#
# In a terminal window type:

# %% [raw]
# conda config --add channels conda-forge
# conda config --add channels hydrocomputing

# %% [markdown]
# Create a conda environment by typing:

# %% [raw]
# conda create -n pymf6_313 python=3.13

# %% [markdown]
# Answer “Yes” to the question(s) and type enter.
#
# Next, type:

# %% [raw]
# conda activate pymf6_313

# %% [markdown]
# ## Install MODFLOW 6

# %% [markdown]
# Download the version for your operating system at "https://github.com/MODFLOW-ORG/modflow6/releases"

# %% [markdown]
# ### Configuration

# %% [markdown]
# While you can specify the path to the DLL and executable for each run, it is highly recommended to create a configuration. You need to create a file named pymf6.ini in your home directory. You can find your home directory with different methods. On Windows, the command:

# %% [raw]
# set HOMEPATH

# %% [markdown]
# Posix systems such as Linux and MacOSX, the command:

# %% [raw]
# echo $HOME

# %% [markdown]
# The file pymf6.ini needs have to have this content on Windows:

# %% [raw]
# [paths]
# dll_path = path\to\mf6\bin\libmf6.dll
# exe_path = path\to\mf6\bin\mf6.exe

# %% [markdown]
# On Linux:

# %% [raw]
# [paths]
# dll_path = path/to/mf6/bin/libmf6.so
# exe_path = path/to/mf6/bin/mf6

# %% [markdown]
# On MacOSX:

# %% [raw]
# [paths]
# dll_path = path/to/mf6/bin/libmf6.dylib
# exe_path = path/to/mf6/bin/mf6

# %% [markdown]
# Replace the path path/to/mf6/bin/ with with your absolute path to the MODFLOW 6 directory bin that contains the shared library and the executable you downloaded from the USGS website (see section “Installation” above).

# %% [markdown]
# ### Test the Install

# %% [markdown]
# On the command line type:

# %% [raw]
# pymf6

# %% [markdown]
# ## Documentation

# %% [markdown]
# "https://pymf6.readthedocs.io/en/latest/"
