# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from pathlib import Path

# %%
from pymf6_tools.make_model import run_simulation

# %%
from pymf6_tools.plotting import show_heads, show_well_head, show_concentration, show_bcs

# %%
from pymf6_tools.base_model import BASE_MODEL_DATA

# %%
BASE_MODEL_DATA
# Out:
# {'times': (10.0, 120, 1.0),
#  'time_units': 'DAYS',
#  'length_units': 'meters',
#  'repeat_times': 3,
#  'nrow': 15,
#  'ncol': 10,
#  'nlay': 3,
#  'delr': 100.0,
#  'delc': 100.0,
#  'top': 15.0,
#  'botm': [-5.0, -10.0, -15.0],
#  'k': [0.5, 6e-06, 0.5],
#  'k33': [0.1, 0.002, 0.3],
#  'sy': 0.2,
#  'ss': 1e-06,
#  'initial_head': 10.0,
#  'chd': [[(0, 0, 0), 10.0], [(0, 14, 9), 10.0]],
#  'transport': False,
#  'river': False}

# %%
model_path = Path('models/transport_river_base').absolute()
model_name = 'transriver'

# %%
run_simulation(model_path)

# %%
show_bcs?
# Out:
# Signature:
# show_bcs(
#     model_path,
#     name,
#     title='Boundary Conditions',
#     bc_names=('chd', 'wel', 'riv'),
#     show_grid=True,
# )
# Docstring: Show location of boundary conditions.
# File:      ~/Dev/pymf6-validation/.pixi/envs/default/lib/python3.13/site-packages/pymf6_tools/plotting.py
# Type:      function

# %%
show_bcs(model_path, model_name, bc_names=('chd', 'riv-1', 'wel'))

# %%
show_heads(model_path, model_name, show_wells=False)

# %%
show_well_head?
# Out:
# Signature:
# show_well_head(
#     wel_coords,
#     model_path,
#     model_name,
#     times,
#     title='',
#     y_start=0.3,
#     y_end=1.05,
#     upper_head_limit=None,
#     lower_head_limit=None,
#     x=(0, 32),
# )
# Docstring: Plot head at well over time.
# File:      ~/Dev/pymf6-validation/.pixi/envs/default/lib/python3.13/site-packages/pymf6_tools/plotting.py
# Type:      function

# %%
show_well_head((0, 4, 4), model_path, model_name, BASE_MODEL_DATA['times'], y_start=0, y_end=20)
# Out:
# <Axes: xlabel='Time (d)', ylabel='Groundwater level (m)'>
