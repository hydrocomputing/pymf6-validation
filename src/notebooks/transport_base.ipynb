# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from pymf6_tools.make_model import run_simulation

# %%
from pymf6_tools.plotting import show_heads, show_well_head, show_concentration, show_bcs, contour_well_heads

# %%
from pymf6_tools.base_model import BASE_MODEL_DATA, BASE_TRANSPORT_MODEL_DATA, BASE_WELL_MODEL_DATA

# %%
#set model path 
model_path = r'models/transport_base'
model_name = 'transbase'
#well_coords = BASE_WELL_MODEL_DATA['wells']['coords']

# %%
run_simulation(model_path)

# %%
show_bcs(model_path, model_name, bc_names=('chd', 'wel'), show_grid=True)

# %%
show_heads(model_path, model_name, show_wells=False)

# %%
show_well_head?
# Out:
# Signature:
# show_well_head(
#     wel_coords,
#     model_path,
#     model_name,
#     times,
#     title='',
#     y_start=0.3,
#     y_end=1.05,
#     upper_head_limit=None,
#     lower_head_limit=None,
#     x=(0, 32),
# )
# Docstring: Plot head at well over time.
# File:      ~/hydrocomputing/projects/2021/003_ModSimple_Phase2/Bearbeitung/devtests/pymf6test/.pixi/envs/default/lib/python3.13/site-packages/pymf6_tools/plotting.py
# Type:      function

# %%
contour_well_heads(model_path, model_name, title="Well heads contour")

# %%
show_well_head((0, 4, 4), model_path, model_name, BASE_MODEL_DATA['times'], y_start=0, y_end=20)
# Out:
# <Axes: xlabel='Time (d)', ylabel='Groundwater level (m)'>
